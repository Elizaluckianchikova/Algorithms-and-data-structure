# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizaluckianchikova/Algorithms-and-data-structure/blob/main/Monte_Carlo_in_bio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Метод Монте-Карло **
#
# Метод Монте-Карло - это статистический метод, который используется для решения различных задач путем проведения случайных экспериментов. В контексте программирования на Python модель Монте-Карло может быть использована для оценки или аппроксимации значений функций, вычисления интегралов, моделирования случайных процессов и т.д.
# В этом примере функция monte_carlo_pi использует метод Монте-Карло для оценки числа π путем генерации случайных точек в квадрате со стороной 1 и подсчета того, сколько из них попадает внутрь четверти круга радиусом 1. Затем она вычисляет отношение площадей квадрата и четверти круга, умножает его на 4 и возвращает оценку числа π.
#
# Метод Монте-Карло может быть применен для решения более сложных задач, таких как моделирование финансовых рынков, оценка интегралов с использованием метода Монте-Карло и многое другое.

# %%
import random

def monte_carlo_pi(num_samples):
    inside_circle = 0
    for _ in range(num_samples):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <= 1:
            inside_circle += 1
    return 4 * inside_circle / num_samples

num_samples = 1000000
estimated_pi = monte_carlo_pi(num_samples)
print(f"Оценка числа π с использованием {num_samples} выборок: {estimated_pi}")
# Out:
# Оценка числа π с использованием 1000000 выборок: 3.143432

# %%
import random

def monte_carlo_integration(func, a, b, num_samples):
    total = 0
    for _ in range(num_samples):
        x = random.uniform(a, b)
        total += func(x)
    return (b - a) * total / num_samples

# Пример: оценка определенного интеграла функции f(x) = x^2 на интервале [0, 1]
def func(x):
    return x**2

a = 0
b = 1
num_samples = 1000000
estimated_integral = monte_carlo_integration(func, a, b, num_samples)
print(f"Оценка определенного интеграла: {estimated_integral}")
# Out:
# Оценка определенного интеграла: 0.33347580714467445

# %% [markdown]
# **Метод Монте-Карло для моделирования генетической  популяции **
#
# Метод Монте-Карло - это статистический метод моделирования, который может быть использован для моделирования генетической популяции питон. Для этого можно использовать следующие шаги:
#
# 1. Определение начальных условий: определите начальное количество особей в популяции, их генетическое разнообразие и другие параметры, которые могут влиять на генетическую структуру популяции.
#
# 2. Создание модели: используйте метод Монте-Карло для создания модели, которая будет учитывать случайные изменения в генетической структуре популяции. Это может включать в себя случайное скрещивание, мутации, миграцию и другие процессы.
#
# 3. Итерационное моделирование: запустите модель на нескольких итерациях, чтобы увидеть, как изменяется генетическая структура популяции с течением времени и какие факторы оказывают на нее наибольшее влияние.
#
# 4. Анализ результатов: проанализируйте результаты моделирования, чтобы понять, какие факторы оказывают наибольшее влияние на генетическую структуру популяции и какие изменения могут произойти в будущем.
#
# Метод Монте-Карло может быть полезным инструментом для изучения динамики генетической популяции питон и предсказания ее будущего состояния при различных условиях.

# %%
import random

# Начальные условия
initial_population = 1000
mutation_rate = 0.01
generations = 100

# Моделирование популяции
population = [random.choice(['A', 'T', 'G', 'C']) for _ in range(initial_population)]

for generation in range(generations):
    # Мутации
    for i in range(initial_population):
        if random.random() < mutation_rate:
            population[i] = random.choice(['A', 'T', 'G', 'C'])

    # Статистика генетической структуры
    nucleotide_counts = {nucleotide: population.count(nucleotide) for nucleotide in ['A', 'T', 'G', 'C']}
    print(f"Generation {generation+1}: {nucleotide_counts}")
# Out:
# Generation 1: {'A': 253, 'T': 250, 'G': 251, 'C': 246}
# Generation 2: {'A': 252, 'T': 250, 'G': 251, 'C': 247}
# Generation 3: {'A': 253, 'T': 248, 'G': 253, 'C': 246}
# Generation 4: {'A': 252, 'T': 245, 'G': 255, 'C': 248}
# Generation 5: {'A': 254, 'T': 245, 'G': 258, 'C': 243}
# Generation 6: {'A': 256, 'T': 245, 'G': 258, 'C': 241}
# Generation 7: {'A': 254, 'T': 243, 'G': 261, 'C': 242}
# Generation 8: {'A': 252, 'T': 244, 'G': 261, 'C': 243}
# Generation 9: {'A': 252, 'T': 247, 'G': 259, 'C': 242}
# Generation 10: {'A': 250, 'T': 249, 'G': 257, 'C': 244}
# Generation 11: {'A': 256, 'T': 245, 'G': 257, 'C': 242}
# Generation 12: {'A': 253, 'T': 247, 'G': 257, 'C': 243}
# Generation 13: {'A': 252, 'T': 243, 'G': 259, 'C': 246}
# Generation 14: {'A': 250, 'T': 247, 'G': 260, 'C': 243}
# Generation 15: {'A': 253, 'T': 248, 'G': 258, 'C': 241}
# Generation 16: {'A': 254, 'T': 249, 'G': 257, 'C': 240}
# Generation 17: {'A': 253, 'T': 250, 'G': 261, 'C': 236}
# Generation 18: {'A': 251, 'T': 252, 'G': 263, 'C': 234}
# Generation 19: {'A': 253, 'T': 252, 'G': 262, 'C': 233}
# Generation 20: {'A': 251, 'T': 253, 'G': 263, 'C': 233}
# Generation 21: {'A': 252, 'T': 253, 'G': 261, 'C': 234}
# Generation 22: {'A': 250, 'T': 255, 'G': 263, 'C': 232}
# Generation 23: {'A': 249, 'T': 258, 'G': 261, 'C': 232}
# Generation 24: {'A': 248, 'T': 262, 'G': 261, 'C': 229}
# Generation 25: {'A': 247, 'T': 259, 'G': 261, 'C': 233}
# Generation 26: {'A': 245, 'T': 261, 'G': 263, 'C': 231}
# Generation 27: {'A': 242, 'T': 260, 'G': 265, 'C': 233}
# Generation 28: {'A': 241, 'T': 262, 'G': 265, 'C': 232}
# Generation 29: {'A': 242, 'T': 265, 'G': 263, 'C': 230}
# Generation 30: {'A': 244, 'T': 265, 'G': 261, 'C': 230}
# Generation 31: {'A': 244, 'T': 265, 'G': 261, 'C': 230}
# Generation 32: {'A': 242, 'T': 267, 'G': 262, 'C': 229}
# Generation 33: {'A': 243, 'T': 267, 'G': 262, 'C': 228}
# Generation 34: {'A': 247, 'T': 261, 'G': 263, 'C': 229}
# Generation 35: {'A': 247, 'T': 261, 'G': 263, 'C': 229}
# Generation 36: {'A': 247, 'T': 260, 'G': 261, 'C': 232}
# Generation 37: {'A': 247, 'T': 258, 'G': 262, 'C': 233}
# Generation 38: {'A': 246, 'T': 260, 'G': 260, 'C': 234}
# Generation 39: {'A': 247, 'T': 263, 'G': 256, 'C': 234}
# Generation 40: {'A': 246, 'T': 265, 'G': 255, 'C': 234}
# Generation 41: {'A': 246, 'T': 263, 'G': 253, 'C': 238}
# Generation 42: {'A': 247, 'T': 264, 'G': 254, 'C': 235}
# Generation 43: {'A': 247, 'T': 267, 'G': 254, 'C': 232}
# Generation 44: {'A': 247, 'T': 267, 'G': 255, 'C': 231}
# Generation 45: {'A': 249, 'T': 265, 'G': 256, 'C': 230}
# Generation 46: {'A': 252, 'T': 264, 'G': 253, 'C': 231}
# Generation 47: {'A': 250, 'T': 265, 'G': 254, 'C': 231}
# Generation 48: {'A': 251, 'T': 262, 'G': 253, 'C': 234}
# Generation 49: {'A': 247, 'T': 267, 'G': 253, 'C': 233}
# Generation 50: {'A': 246, 'T': 268, 'G': 255, 'C': 231}
# Generation 51: {'A': 247, 'T': 266, 'G': 255, 'C': 232}
# Generation 52: {'A': 249, 'T': 265, 'G': 255, 'C': 231}
# Generation 53: {'A': 247, 'T': 264, 'G': 257, 'C': 232}
# Generation 54: {'A': 245, 'T': 265, 'G': 257, 'C': 233}
# Generation 55: {'A': 244, 'T': 261, 'G': 260, 'C': 235}
# Generation 56: {'A': 244, 'T': 257, 'G': 263, 'C': 236}
# Generation 57: {'A': 242, 'T': 258, 'G': 263, 'C': 237}
# Generation 58: {'A': 241, 'T': 261, 'G': 262, 'C': 236}
# Generation 59: {'A': 242, 'T': 261, 'G': 261, 'C': 236}
# Generation 60: {'A': 241, 'T': 262, 'G': 261, 'C': 236}
# Generation 61: {'A': 241, 'T': 261, 'G': 262, 'C': 236}
# Generation 62: {'A': 244, 'T': 260, 'G': 260, 'C': 236}
# Generation 63: {'A': 241, 'T': 260, 'G': 259, 'C': 240}
# Generation 64: {'A': 240, 'T': 259, 'G': 259, 'C': 242}
# Generation 65: {'A': 242, 'T': 259, 'G': 259, 'C': 240}
# Generation 66: {'A': 243, 'T': 257, 'G': 259, 'C': 241}
# Generation 67: {'A': 245, 'T': 255, 'G': 260, 'C': 240}
# Generation 68: {'A': 245, 'T': 257, 'G': 259, 'C': 239}
# Generation 69: {'A': 245, 'T': 257, 'G': 262, 'C': 236}
# Generation 70: {'A': 247, 'T': 259, 'G': 257, 'C': 237}
# Generation 71: {'A': 248, 'T': 258, 'G': 257, 'C': 237}
# Generation 72: {'A': 247, 'T': 255, 'G': 258, 'C': 240}
# Generation 73: {'A': 249, 'T': 258, 'G': 255, 'C': 238}
# Generation 74: {'A': 250, 'T': 255, 'G': 256, 'C': 239}
# Generation 75: {'A': 247, 'T': 254, 'G': 257, 'C': 242}
# Generation 76: {'A': 248, 'T': 254, 'G': 259, 'C': 239}
# Generation 77: {'A': 251, 'T': 251, 'G': 260, 'C': 238}
# Generation 78: {'A': 252, 'T': 252, 'G': 260, 'C': 236}
# Generation 79: {'A': 250, 'T': 250, 'G': 262, 'C': 238}
# Generation 80: {'A': 248, 'T': 252, 'G': 261, 'C': 239}
# Generation 81: {'A': 249, 'T': 251, 'G': 261, 'C': 239}
# Generation 82: {'A': 253, 'T': 250, 'G': 260, 'C': 237}
# Generation 83: {'A': 252, 'T': 250, 'G': 260, 'C': 238}
# Generation 84: {'A': 254, 'T': 248, 'G': 261, 'C': 237}
# Generation 85: {'A': 256, 'T': 247, 'G': 260, 'C': 237}
# Generation 86: {'A': 257, 'T': 250, 'G': 261, 'C': 232}
# Generation 87: {'A': 256, 'T': 251, 'G': 259, 'C': 234}
# Generation 88: {'A': 253, 'T': 251, 'G': 259, 'C': 237}
# Generation 89: {'A': 252, 'T': 250, 'G': 260, 'C': 238}
# Generation 90: {'A': 255, 'T': 246, 'G': 260, 'C': 239}
# Generation 91: {'A': 257, 'T': 249, 'G': 260, 'C': 234}
# Generation 92: {'A': 256, 'T': 249, 'G': 261, 'C': 234}
# Generation 93: {'A': 258, 'T': 248, 'G': 260, 'C': 234}
# Generation 94: {'A': 259, 'T': 244, 'G': 262, 'C': 235}
# Generation 95: {'A': 258, 'T': 244, 'G': 264, 'C': 234}
# Generation 96: {'A': 259, 'T': 243, 'G': 264, 'C': 234}
# Generation 97: {'A': 260, 'T': 243, 'G': 263, 'C': 234}
# Generation 98: {'A': 263, 'T': 242, 'G': 262, 'C': 233}
# Generation 99: {'A': 264, 'T': 242, 'G': 261, 'C': 233}
# Generation 100: {'A': 264, 'T': 241, 'G': 262, 'C': 233}

# %%
#Метод Монте-Карло для моделирования эпидемии
import random

# Начальные условия
population_size = 1000
initial_infected = 10
transmission_rate = 0.1
recovery_rate = 0.05
simulation_days = 100

# Инициализация популяции
population = ['healthy'] * (population_size - initial_infected) + ['infected'] * initial_infected

# Моделирование эпидемии
for day in range(simulation_days):
    new_infections = 0
    new_recoveries = 0

    for i in range(population_size):
        if population[i] == 'infected':
            # Передача инфекции другим особям
            for j in range(population_size):
                if population[j] == 'healthy' and random.random() < transmission_rate:
                    population[j] = 'infected'
                    new_infections += 1

            # Выздоровление от инфекции
            if random.random() < recovery_rate:
                population[i] = 'recovered'
                new_recoveries += 1

    print(f"Day {day+1}: New infections: {new_infections}, New recoveries: {new_recoveries}")

# Вывод статистики
final_infected_count = population.count('infected')
final_recovered_count = population.count('recovered')
print(f"Simulation finished. Final infected count: {final_infected_count}, Final recovered count: {final_recovered_count}")
# Out:
# Day 1: New infections: 639, New recoveries: 1
# Day 2: New infections: 351, New recoveries: 52
# Day 3: New infections: 0, New recoveries: 54
# Day 4: New infections: 0, New recoveries: 52
# Day 5: New infections: 0, New recoveries: 35
# Day 6: New infections: 0, New recoveries: 50
# Day 7: New infections: 0, New recoveries: 32
# Day 8: New infections: 0, New recoveries: 32
# Day 9: New infections: 0, New recoveries: 36
# Day 10: New infections: 0, New recoveries: 29
# Day 11: New infections: 0, New recoveries: 36
# Day 12: New infections: 0, New recoveries: 24
# Day 13: New infections: 0, New recoveries: 34
# Day 14: New infections: 0, New recoveries: 31
# Day 15: New infections: 0, New recoveries: 30
# Day 16: New infections: 0, New recoveries: 16
# Day 17: New infections: 0, New recoveries: 18
# Day 18: New infections: 0, New recoveries: 19
# Day 19: New infections: 0, New recoveries: 21
# Day 20: New infections: 0, New recoveries: 21
# Day 21: New infections: 0, New recoveries: 21
# Day 22: New infections: 0, New recoveries: 19
# Day 23: New infections: 0, New recoveries: 14
# Day 24: New infections: 0, New recoveries: 16
# Day 25: New infections: 0, New recoveries: 15
# Day 26: New infections: 0, New recoveries: 10
# Day 27: New infections: 0, New recoveries: 19
# Day 28: New infections: 0, New recoveries: 9
# Day 29: New infections: 0, New recoveries: 15
# Day 30: New infections: 0, New recoveries: 8
# Day 31: New infections: 0, New recoveries: 9
# Day 32: New infections: 0, New recoveries: 8
# Day 33: New infections: 0, New recoveries: 12
# Day 34: New infections: 0, New recoveries: 7
# Day 35: New infections: 0, New recoveries: 9
# Day 36: New infections: 0, New recoveries: 7
# Day 37: New infections: 0, New recoveries: 12
# Day 38: New infections: 0, New recoveries: 5
# Day 39: New infections: 0, New recoveries: 11
# Day 40: New infections: 0, New recoveries: 4
# Day 41: New infections: 0, New recoveries: 3
# Day 42: New infections: 0, New recoveries: 10
# Day 43: New infections: 0, New recoveries: 9
# Day 44: New infections: 0, New recoveries: 6
# Day 45: New infections: 0, New recoveries: 6
# Day 46: New infections: 0, New recoveries: 8
# Day 47: New infections: 0, New recoveries: 4
# Day 48: New infections: 0, New recoveries: 3
# Day 49: New infections: 0, New recoveries: 5
# Day 50: New infections: 0, New recoveries: 4
# Day 51: New infections: 0, New recoveries: 3
# Day 52: New infections: 0, New recoveries: 3
# Day 53: New infections: 0, New recoveries: 4
# Day 54: New infections: 0, New recoveries: 5
# Day 55: New infections: 0, New recoveries: 4
# Day 56: New infections: 0, New recoveries: 7
# Day 57: New infections: 0, New recoveries: 3
# Day 58: New infections: 0, New recoveries: 1
# Day 59: New infections: 0, New recoveries: 1
# Day 60: New infections: 0, New recoveries: 1
# Day 61: New infections: 0, New recoveries: 3
# Day 62: New infections: 0, New recoveries: 1
# Day 63: New infections: 0, New recoveries: 1
# Day 64: New infections: 0, New recoveries: 3
# Day 65: New infections: 0, New recoveries: 1
# Day 66: New infections: 0, New recoveries: 3
# Day 67: New infections: 0, New recoveries: 2
# Day 68: New infections: 0, New recoveries: 5
# Day 69: New infections: 0, New recoveries: 1
# Day 70: New infections: 0, New recoveries: 0
# Day 71: New infections: 0, New recoveries: 2
# Day 72: New infections: 0, New recoveries: 4
# Day 73: New infections: 0, New recoveries: 0
# Day 74: New infections: 0, New recoveries: 0
# Day 75: New infections: 0, New recoveries: 1
# Day 76: New infections: 0, New recoveries: 2
# Day 77: New infections: 0, New recoveries: 3
# Day 78: New infections: 0, New recoveries: 2
# Day 79: New infections: 0, New recoveries: 2
# Day 80: New infections: 0, New recoveries: 3
# Day 81: New infections: 0, New recoveries: 1
# Day 82: New infections: 0, New recoveries: 0
# Day 83: New infections: 0, New recoveries: 3
# Day 84: New infections: 0, New recoveries: 1
# Day 85: New infections: 0, New recoveries: 0
# Day 86: New infections: 0, New recoveries: 0
# Day 87: New infections: 0, New recoveries: 2
# Day 88: New infections: 0, New recoveries: 0
# Day 89: New infections: 0, New recoveries: 1
# Day 90: New infections: 0, New recoveries: 1
# Day 91: New infections: 0, New recoveries: 0
# Day 92: New infections: 0, New recoveries: 1
# Day 93: New infections: 0, New recoveries: 2
# Day 94: New infections: 0, New recoveries: 1
# Day 95: New infections: 0, New recoveries: 0
# Day 96: New infections: 0, New recoveries: 0
# Day 97: New infections: 0, New recoveries: 0
# Day 98: New infections: 0, New recoveries: 0
# Day 99: New infections: 0, New recoveries: 0
# Day 100: New infections: 0, New recoveries: 1
# Simulation finished. Final infected count: 4, Final recovered count: 996
